# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# to visualise al the columns in the dataframe

# %%
dataset=pd.read_csv('IPL Matches 2008-2020.csv')
dataset.head()
pd.pandas.set_option('display.max_columns', None)
##pd.pandas.set_option('display.date_datefirst',None)

# %%
dataset.head()
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2  335984       Delhi  2008-04-19     MF Maharoof
# 3  335985      Mumbai  2008-04-20      MV Boucher
# 4  335986     Kolkata  2008-04-20       DJ Hussey
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
#
#                          team1                        team2  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders
# 1              Kings XI Punjab          Chennai Super Kings
# 2             Delhi Daredevils             Rajasthan Royals
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
dataset.describe()
# Out:
#                  id  neutral_venue  result_margin
# count  8.160000e+02     816.000000     799.000000
# mean   7.563496e+05       0.094363      17.321652
# std    3.058943e+05       0.292512      22.068427
# min    3.359820e+05       0.000000       1.000000
# 25%    5.012278e+05       0.000000       6.000000
# 50%    7.292980e+05       0.000000       8.000000
# 75%    1.082626e+06       0.000000      19.500000
# max    1.237181e+06       1.000000     146.000000

# %%
list(dataset.columns)
# Out:
# ['id',
#  'city',
#  'date',
#  'player_of_match',
#  'venue',
#  'neutral_venue',
#  'team1',
#  'team2',
#  'toss_winner',
#  'toss_decision',
#  'winner',
#  'result',
#  'result_margin',
#  'eliminator',
#  'method',
#  'umpire1',
#  'umpire2']

# %%
dataset.shape
# Out:
# (816, 17)

# %%
dataset.head(5)
# Out:
#          city        date player_of_match  \
# 0   Bangalore  2008-04-18     BB McCullum
# 1  Chandigarh  2008-04-19      MEK Hussey
# 2       Delhi  2008-04-19     MF Maharoof
# 3      Mumbai  2008-04-20      MV Boucher
# 4     Kolkata  2008-04-20       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# 0        Kolkata Knight Riders  Royal Challengers Bangalore         field
# 1          Chennai Super Kings          Chennai Super Kings           bat
# ...

# %%
dataset.drop('date',inplace=True,axis=1)
## we removed date,id because they are not of much importance to our conclusion.we can also remove method since it has just few values rest all others are NaN

# %%
dataset.head(20)
# Out:
#           city player_of_match                                       venue  \
# 0    Bangalore     BB McCullum                       M Chinnaswamy Stadium
# 1   Chandigarh      MEK Hussey  Punjab Cricket Association Stadium, Mohali
# 2        Delhi     MF Maharoof                            Feroz Shah Kotla
# 3       Mumbai      MV Boucher                            Wankhede Stadium
# 4      Kolkata       DJ Hussey                                Eden Gardens
# 5       Jaipur       SR Watson                      Sawai Mansingh Stadium
# 6    Hyderabad        V Sehwag   Rajiv Gandhi International Stadium, Uppal
# 7      Chennai       ML Hayden             MA Chidambaram Stadium, Chepauk
# 8    Hyderabad       YK Pathan   Rajiv Gandhi International Stadium, Uppal
# 9   Chandigarh   KC Sangakkara  Punjab Cricket Association Stadium, Mohali
# 10   Bangalore       SR Watson                       M Chinnaswamy Stadium
# ...

# %%
dataset.eliminator.value_counts()
# Out:
# N    799
# Y     13
# Name: eliminator, dtype: int64

# %%
dataset.drop('method',inplace=True,axis=1)

# %%
dataset.head()
# Out:
#          city player_of_match                                       venue  \
# 0   Bangalore     BB McCullum                       M Chinnaswamy Stadium
# 1  Chandigarh      MEK Hussey  Punjab Cricket Association Stadium, Mohali
# 2       Delhi     MF Maharoof                            Feroz Shah Kotla
# 3      Mumbai      MV Boucher                            Wankhede Stadium
# 4     Kolkata       DJ Hussey                                Eden Gardens
#
#                          team1                        team2  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders
# 1              Kings XI Punjab          Chennai Super Kings
# 2             Delhi Daredevils             Rajasthan Royals
# 3               Mumbai Indians  Royal Challengers Bangalore
# 4        Kolkata Knight Riders              Deccan Chargers
#
#                    toss_winner toss_decision                       winner  \
# 0  Royal Challengers Bangalore         field        Kolkata Knight Riders
# ...

# %%
dataset.toss_decision.value_counts()
# Out:
# field    496
# bat      320
# Name: toss_decision, dtype: int64

# %%
dataset.result.value_counts()
# Out:
# wickets    435
# runs       364
# tie         13
# Name: result, dtype: int64

# %%
list(dataset.columns)
# Out:
# ['city',
#  'player_of_match',
#  'venue',
#  'team1',
#  'team2',
#  'toss_winner',
#  'toss_decision',
#  'winner',
#  'result',
#  'result_margin',
#  'eliminator',
#  'umpire1',
#  'umpire2']

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   city             803 non-null    object
#  1   player_of_match  812 non-null    object
#  2   venue            816 non-null    object
#  3   team1            816 non-null    object
#  4   team2            816 non-null    object
#  5   toss_winner      816 non-null    object
#  6   toss_decision    816 non-null    object
#  7   winner           812 non-null    object
#  8   result           812 non-null    object
#  9   result_margin    799 non-null    float64
#  10  eliminator       812 non-null    object
#  11  umpire1          816 non-null    object
#  12  umpire2          816 non-null    object
# dtypes: float64(1), object(12)
# memory usage: 83.0+ KB

# %%
dataset.describe()
# Out:
#        result_margin
# count     799.000000
# mean       17.321652
# std        22.068427
# min         1.000000
# 25%         6.000000
# 50%         8.000000
# 75%        19.500000
# max       146.000000

# %%
dataset.head()
# Out:
#          city player_of_match                                       venue  \
# 0   Bangalore     BB McCullum                       M Chinnaswamy Stadium
# 1  Chandigarh      MEK Hussey  Punjab Cricket Association Stadium, Mohali
# 2       Delhi     MF Maharoof                            Feroz Shah Kotla
# 3      Mumbai      MV Boucher                            Wankhede Stadium
# 4     Kolkata       DJ Hussey                                Eden Gardens
#
#                          team1                        team2  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders
# 1              Kings XI Punjab          Chennai Super Kings
# 2             Delhi Daredevils             Rajasthan Royals
# 3               Mumbai Indians  Royal Challengers Bangalore
# 4        Kolkata Knight Riders              Deccan Chargers
#
#                    toss_winner toss_decision                       winner  \
# 0  Royal Challengers Bangalore         field        Kolkata Knight Riders
# ...

# %%
dataset.umpire1.value_counts()
# Out:
# HDPK Dharmasena          78
# AK Chaudhary             56
# Asad Rauf                51
# M Erasmus                40
# Aleem Dar                38
# BF Bowden                37
# S Ravi                   37
# BR Doctrove              34
# CB Gaffaney              34
# KN Ananthapadmanabhan    33
# AY Dandekar              28
# C Shamshuddin            22
# NJ Llong                 21
# Nitin Menon              20
# RE Koertzen              20
# S Asnani                 19
# VA Kulkarni              19
# BNJ Oxenford             16
# JD Cloete                16
# YC Barde                 14
# A Nand Kishore           14
# BG Jerling               13
# RK Illingworth           13
# SS Hazare                11
# S Das                    10
# MR Benson                10
# K Hariharan              10
# DJ Harper                 9
# UV Gandhe                 8
# CK Nandan                 8
# IL Howell                 7
# GAV Baxter                7
# RM Deshpande              7
# ...

# %%
from sklearn.model_selection import train_test_split
train_set,train_set = train_test_split(dataset,test_size=0.2,random_state=42)

# %%
categorical_features=[feature for feature in dataset.columns if dataset[feature].dtype=='O']

categorical_features
# Out:
# ['city',
#  'player_of_match',
#  'venue',
#  'team1',
#  'team2',
#  'toss_winner',
#  'toss_decision',
#  'winner',
#  'result',
#  'eliminator',
#  'umpire1']

# %%
for feature in categorical_features:
    temp=dataset.groupby(feature)['winner'].count()/len(dataset)
    temp_df=temp[temp>0.01].index
    dataset[feature]=np.where(dataset[feature].isin(temp_df),dataset[feature],'Rare_var')
    
    

dataset.head(60)
# Out:
#           city player_of_match                                       venue  \
# 0    Bangalore        Rare_var                       M Chinnaswamy Stadium
# 1   Chandigarh      MEK Hussey  Punjab Cricket Association Stadium, Mohali
# 2        Delhi        Rare_var                            Feroz Shah Kotla
# 3       Mumbai        Rare_var                            Wankhede Stadium
# 4      Kolkata        Rare_var                                Eden Gardens
# 5       Jaipur       SR Watson                      Sawai Mansingh Stadium
# 6    Hyderabad        V Sehwag   Rajiv Gandhi International Stadium, Uppal
# 7      Chennai        Rare_var             MA Chidambaram Stadium, Chepauk
# 8    Hyderabad       YK Pathan   Rajiv Gandhi International Stadium, Uppal
# 9   Chandigarh        Rare_var  Punjab Cricket Association Stadium, Mohali
# 10   Bangalore       SR Watson                       M Chinnaswamy Stadium
# ...
